# %%
# https://www.ssa.gov/oact/babynames/limits.html
import pandas as pd
df = pd.read_csv('C:/Users/a550859/Desktop/py training/yob1880.txt')

# %%
df
# Out:
#            Mary  F  7065
# 0          Anna  F  2604
# 1          Emma  F  2003
# 2     Elizabeth  F  1939
# 3        Minnie  F  1746
# 4      Margaret  F  1578
# 5           Ida  F  1472
# 6         Alice  F  1414
# 7        Bertha  F  1320
# 8         Sarah  F  1288
# 9         Annie  F  1258
# 10        Clara  F  1226
# 11         Ella  F  1156
# 12     Florence  F  1063
# 13         Cora  F  1045
# 14       Martha  F  1040
# 15        Laura  F  1012
# 16       Nellie  F   995
# 17        Grace  F   982
# 18       Carrie  F   949
# 19        Maude  F   858
# 20        Mabel  F   808
# 21       Bessie  F   796
# 22       Jennie  F   793
# 23     Gertrude  F   787
# 24        Julia  F   783
# 25       Hattie  F   769
# 26        Edith  F   768
# 27       Mattie  F   704
# 28         Rose  F   700
# 29    Catherine  F   688
# ...         ... ..   ...
# 1969      Philo  M     5
# 1970    Phineas  M     5
# 1971    Presley  M     5
# 1972     Ransom  M     5
# 1973      Reece  M     5
# ...

# %%
df = pd.read_csv('C:/Users/a550859/Desktop/py training/yob1880.txt',names=['name','gender','count'])

# %%
df
# Out:
#            name gender  count
# 0          Mary      F   7065
# 1          Anna      F   2604
# 2          Emma      F   2003
# 3     Elizabeth      F   1939
# 4        Minnie      F   1746
# 5      Margaret      F   1578
# 6           Ida      F   1472
# 7         Alice      F   1414
# 8        Bertha      F   1320
# 9         Sarah      F   1288
# 10        Annie      F   1258
# 11        Clara      F   1226
# 12         Ella      F   1156
# 13     Florence      F   1063
# 14         Cora      F   1045
# 15       Martha      F   1040
# 16        Laura      F   1012
# 17       Nellie      F    995
# 18        Grace      F    982
# 19       Carrie      F    949
# 20        Maude      F    858
# 21        Mabel      F    808
# 22       Bessie      F    796
# 23       Jennie      F    793
# 24     Gertrude      F    787
# 25        Julia      F    783
# 26       Hattie      F    769
# 27        Edith      F    768
# 28       Mattie      F    704
# 29         Rose      F    700
# ...

# %%
df.T
# Out:
#         0     1     2          3       4         5     6      7       8     \
# name    Mary  Anna  Emma  Elizabeth  Minnie  Margaret   Ida  Alice  Bertha
# gender     F     F     F          F       F         F     F      F       F
# count   7065  2604  2003       1939    1746      1578  1472   1414    1320
#
#          9       ...         1990  1991 1992     1993  1994    1995    1996  \
# name    Sarah    ...      Unknown  Vann  Wes  Winston  Wood  Woodie  Worthy
# gender      F    ...            M     M    M        M     M       M       M
# count    1288    ...            5     5    5        5     5       5       5
#
#           1997  1998       1999
# name    Wright  York  Zachariah
# gender       M     M          M
# count        5     5          5
#
# [3 rows x 2000 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
# name      2000 non-null object
# gender    2000 non-null object
# count     2000 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 47.0+ KB

# %%
df.dtypes
# Out:
# name      object
# gender    object
# count      int64
# dtype: object

# %%
df.gender.value_counts()
# Out:
# M    1058
# F     942
# Name: gender, dtype: int64

# %%
df['gender']=df.gender.astype('category') #saves memory

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
# name      2000 non-null object
# gender    2000 non-null category
# count     2000 non-null int64
# dtypes: category(1), int64(1), object(1)
# memory usage: 33.3+ KB

# %%
df.head(10)
# Out:
#         name gender  count
# 0       Mary      F   7065
# 1       Anna      F   2604
# 2       Emma      F   2003
# 3  Elizabeth      F   1939
# 4     Minnie      F   1746
# 5   Margaret      F   1578
# 6        Ida      F   1472
# 7      Alice      F   1414
# 8     Bertha      F   1320
# 9      Sarah      F   1288

# %%
df.shape
# Out:
# (2000, 3)

# %% [markdown]
# # Axes

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=2000, step=1),
#  Index(['name', 'gender', 'count'], dtype='object')]

# %%
len(df.axes)
# Out:
# 2

# %%
df.axes[1]
# Out:
# Index(['name', 'gender', 'count'], dtype='object')

# %%
df.sort_index(axis=0,ascending = False)
# Out:
#            name gender  count
# 1999  Zachariah      M      5
# 1998       York      M      5
# 1997     Wright      M      5
# 1996     Worthy      M      5
# 1995     Woodie      M      5
# 1994       Wood      M      5
# 1993    Winston      M      5
# 1992        Wes      M      5
# 1991       Vann      M      5
# 1990    Unknown      M      5
# 1989      Tommy      M      5
# 1988     Tilmon      M      5
# 1987  Theophile      M      5
# 1986   Theadore      M      5
# 1985   Sylvanus      M      5
# 1984   Starling      M      5
# 1983   Spurgeon      M      5
# 1982   Sheppard      M      5
# 1981   Schuyler      M      5
# 1980     Santos      M      5
# 1979     Samual      M      5
# 1978    Sampson      M      5
# 1977    Rowland      M      5
# 1976    Roswell      M      5
# 1975       Rene      M      5
# 1974      Reece      M      5
# 1973     Ransom      M      5
# 1972    Presley      M      5
# 1971    Phineas      M      5
# 1970      Philo      M      5
# ...

# %%
df.sort_index(axis=0,ascending = False)
# Out:
#            name gender  count
# 1999  Zachariah      M      5
# 1998       York      M      5
# 1997     Wright      M      5
# 1996     Worthy      M      5
# 1995     Woodie      M      5
# 1994       Wood      M      5
# 1993    Winston      M      5
# 1992        Wes      M      5
# 1991       Vann      M      5
# 1990    Unknown      M      5
# 1989      Tommy      M      5
# 1988     Tilmon      M      5
# 1987  Theophile      M      5
# 1986   Theadore      M      5
# 1985   Sylvanus      M      5
# 1984   Starling      M      5
# 1983   Spurgeon      M      5
# 1982   Sheppard      M      5
# 1981   Schuyler      M      5
# 1980     Santos      M      5
# 1979     Samual      M      5
# 1978    Sampson      M      5
# 1977    Rowland      M      5
# 1976    Roswell      M      5
# 1975       Rene      M      5
# 1974      Reece      M      5
# 1973     Ransom      M      5
# 1972    Presley      M      5
# 1971    Phineas      M      5
# 1970      Philo      M      5
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1997, 1998, 1999], dtype=int64)

# %%
df.index.unique ()
# Out:
# array([   0,    1,    2, ..., 1997, 1998, 1999], dtype=int64)

# %%
df.index.duplicated().any()
# Out:
# False

# %%
dupe_index = pd.Index([1,1,1])

# %%
df.axes[0] == df.index
# Out:
# array([ True,  True,  True, ...,  True,  True,  True], dtype=bool)

# %%
df.axes[0] is df.index
# Out:
# True

# %%
df.describe()
# Out:
#              count
# count  2000.000000
# mean    100.742000
# std     466.108304
# min       5.000000
# 25%       7.000000
# 50%      13.000000
# 75%      41.250000
# max    9655.000000

# %%
df.gender.describe()
# Out:
# count     2000
# unique       2
# top          M
# freq      1058
# Name: gender, dtype: object

# %%
df[df.name == 'Clara']
# Out:
#        name gender  count
# 11    Clara      F   1226
# 1633  Clara      M      8

# %%
df.groupby('gender').sum()
# Out:
#          count
# gender
# F        90993
# M       110491

# %% [markdown]
# # Histograms

# %%
# %matplotlib inline

# %%
df['count'].hist()

# %%
ax = df['count'].hist()
ax.set_ylim([0,10])
# Out:
# (0, 10)

# %%
df['count'].plot(kind='hist')

# %%
ax = df['count'].plot(kind='hist')
ax.set_ylim([0,10])
# Out:
# (0, 10)

# %%
df[df['count']>5000]
# Out:
#         name gender  count
# 0       Mary      F   7065
# 942     John      M   9655
# 943  William      M   9532
# 944    James      M   5927
# 945  Charles      M   5348
# 946   George      M   5126

# %%
ax = df.plot(kind='box')
ax.set_ylim([0,100])
# Out:
# (0, 100)

# %%
df['count'].describe()
# Out:
# count    2000.000000
# mean      100.742000
# std       466.108304
# min         5.000000
# 25%         7.000000
# 50%        13.000000
# 75%        41.250000
# max      9655.000000
# Name: count, dtype: float64

# %%
df['count'].plot(kind = 'pie')
